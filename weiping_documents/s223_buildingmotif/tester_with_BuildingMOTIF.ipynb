# %%
import pyshacl
from rdflib import OWL, RDF, RDFS, SH, Graph, Namespace

# running in si-builder venv

# %%
S223 = Namespace("http://data.ashrae.org/standard223#")

# %%
g = Graph()

g.parse('MODEL_SP223_core-v1.0.ttl', format = 'ttl')

g.parse('VOCAB_SP223_enumeration-v1.0.ttl', format = 'ttl')
g.parse('MODEL_SP223_equipment-v1.0.ttl', format = 'ttl')
g.parse('EQUIPMENTS_EXT_SP223.ttl', format = 'ttl')



g.parse('G36_SP223-v1.0_short.ttl', format = 'ttl')



g.parse('G36_dataGraph_VAV4-2.ttl', format = 'ttl')







og = Graph()
pyshacl.rdfutil.clone.clone_graph(g, og)
sg = Graph()
pyshacl.rdfutil.clone.clone_graph(g, sg)



valid, report_graph, report_text = pyshacl.validate(
    data_graph=g,
    shacl_graph=g,
    advanced=True,
    js=True,
    allow_warnings=False,
    inplace=True,
    iterate_rules=True, # If you iterate rules, this SPARQL construct for chain_rule won't work
)

# 'ex:Generator' in report_text
# print(report_text)

# find the prefix definitions so the select can find them
namespace_map = {}
for prefix, uriref in report_graph.namespaces():
    namespace_map[prefix] = Namespace(uriref)
if "sh" not in namespace_map:
    namespace_map["sh"] = SH

# find the validation results
# Currently filtering out info in qs
qs = """
    SELECT ?resultSeverity ?sourceShape ?resultMessage ?focusNode ?value
    WHERE {
        # ?report rdf:type sh:ValidationReport .
        # ?report sh:result ?result .
        # ?result sh:focusNode ?focusNode .
        OPTIONAL { ?result sh:resultMessage ?resultMessage } .
        # ?result sh:resultSeverity ?resultSeverity .
        # ?result sh:sourceShape ?sourceShape .
        OPTIONAL { ?result sh:value ?value } .
        # FILTER(?resultSeverity = s223:g36).
        }
    """

# pretty colors
color_map = {SH.Violation: 33, SH.Info: 34, SH.Warning: 35, S223.g36: 36}

# run the query, sort the results
results = sorted(report_graph.query(qs, initNs=namespace_map))

prev = None
for resultSeverity, sourceShape, resultMessage, focusNode, value in results:
    if sourceShape != prev:
        color = color_map[resultSeverity]
        if resultMessage:
            print(f"\x1b[{color}m{resultMessage}\x1b[0m")
        else:
            print(f"\x1b[{color}m{sourceShape}\x1b[0m")
        prev = sourceShape
    print(f"    {focusNode}{' ' + value if value else ''}")
# Out:
# /Users/huangwp/opt/anaconda3/lib/python3.8/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: rkzeug is an invalid version and will not be supported in a future release
#   warnings.warn(

# %%
added_triples = g - og
added_triples.print()

# %%
print(report_text)
# Out:
# Validation Report
# Conforms: True

# %% [markdown]
# # Start BuildingMOTIF

# %%
# import necessary BuildingMOTIF libraries
from rdflib import Namespace
from buildingmotif import BuildingMOTIF
from buildingmotif.dataclasses import Model, Library
from buildingmotif.namespaces import BRICK # import this to make writing URIs easier

# %%
# Create an in-memory BuildingMOTIF instance
bm = BuildingMOTIF("sqlite://")

# create the namespace for the building
BLDG = Namespace('urn:bldg/')


# create the building model and add a description
model = Model.create(BLDG, description="This is a test model for a simple building")

# %% [markdown]
# # Load data graphs and shape graphs in BuildingMOTIF

# %%
# load the BRICK model you created
model.graph.parse("G36_dataGraph_VAV4-2.ttl", format="ttl")
# Out:
# <Graph identifier=1058b5b0-9cff-4d05-b9b6-480661364827 (<class 'rdflib.graph.Graph'>)>

# %%
s223_shape_graph = Library.load(ontology_graph="223p.ttl",overwrite=False)

# %%
#constraint1 = Library.load(ontology_graph="../../223standard/models/MODEL_SP223_core-v1.0.ttl")
#constraint2 = Library.load(ontology_graph="../../223standard/vocab/VOCAB_SP223_enumeration-v1.0.ttl")
#constraint3 = Library.load(ontology_graph="../../223standard/models/MODEL_SP223_equipment-v1.0.ttl")
#constraint4 = Library.load(ontology_graph="../../223standard/extensions/EQUIPMENTS_EXT_SP223.ttl")

constraint1 = Library.load(ontology_graph="MODEL_SP223_core-v1.0.ttl")
constraint2 = Library.load(ontology_graph="VOCAB_SP223_enumeration-v1.0.ttl")
constraint3 = Library.load(ontology_graph="MODEL_SP223_equipment-v1.0.ttl")
constraint4 = Library.load(ontology_graph="EQUIPMENTS_EXT_SP223.ttl")

# %%
constraint_shape = Library.load(ontology_graph="G36_SP223-v1.0_short.ttl")

# %%
# load the ".yaml" templates from a folder named "my-templates" into the variable "lib"
lib = Library.load(directory="s223-templates",overwrite=False)

# %%
# gather all the ".ttl" constraints shape graphs in one place
all_shape_graphs = [
    s223_shape_graph.get_shape_collection(),
    constraint1.get_shape_collection(),
    constraint2.get_shape_collection(),
    constraint3.get_shape_collection(),
    constraint4.get_shape_collection(),
    constraint_shape.get_shape_collection(),
    lib.get_shape_collection()
]

# %%
# view the content of the BRICK model
print(model.graph.serialize())
# Out:
# @prefix ex: <http://example.org#> .
# @prefix g36: <http://data.ashrae.org/standard223/1.0/extension/g36#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix quantitykind: <http://qudt.org/vocab/quantitykind/> .
# @prefix qudt: <http://qudt.org/schema/qudt/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
# @prefix unit: <http://qudt.org/vocab/unit/> .
#
# g36: a owl:Ontology ;
#     owl:imports <http://data.ashrae.org/standard223/1.0/collections/MODEL_SP223_all-v1.0.ttl>,
#         <http://data.ashrae.org/standard223/1.0/extensions/G36-rules_SP223-v1.0.shapes.ttl>,
#         <http://data.ashrae.org/standard223/1.0/model/all> .
#
# ex:AirFlowStation42 a g36:AirFlowStation ;
#     rdfs:label "Supply Airflow Sensor" ;
#     s223:hasMeasurementLocation ex:DamperInlet42 ;
#     s223:measuresSubstance s223:Medium-Air ;
#     s223:observes ex:SupplyAirflow42 .
#
# ex:TemperatureSensor a g36:TemperatureSensor ;
#     s223:hasMeasurementLocation ex:VAVReheat ;
#     s223:observes ex:VAVSupplyAirTemp .
#
# ex:WindowSwitch a s223:Sensor ;
#     rdfs:label "Window Switch Sensor" ;
#     s223:hasMeasurementLocation ex:Window ;
#     s223:observes ex:WindowSwitchOnOff .
#
# ex:Zone a g36:Zone ;
#     rdfs:label "The Zone" ;
#     s223:contains ex:Space1 ;
#     s223:hasDomain s223:Domain-HVAC ;
#     s223:hasProperty ex:WindowSwitchOnOff,
#         ex:ZoneCO2,
#         ex:ZoneOccupancy,
#         ex:ZoneTemp .
#
# owl:Class rdfs:subClassOf rdfs:Class .
#
# owl:DatatypeProperty rdfs:subClassOf rdf:Property .
#
# <urn:bldg/> a owl:Ontology .
#
# s223:HeatExchanger-Heating a s223:EnumerationKind-Role,
#         s223:Role-HeatExchanger .
#
# ex:Damper42 a g36:Damper42 ;
#     rdfs:label "Damper 42" ;
#     s223:connectedTo ex:HotWaterCoil ;
#     s223:hasConnectionPoint ex:DamperInlet42,
#         ex:DamperOutlet42 ;
#     s223:hasProperty ex:DamperPositionCommand42 .
#
# ex:DamperOutlet42 a s223:OutletConnectionPoint ;
#     rdfs:label "Damper Outlet 42" ;
#     s223:connectsThrough ex:AirAfterDamperBeforeHeatingCoil ;
#     s223:hasMedium s223:Medium-Air .
#
# ex:DamperPositionCommand42 a s223:QuantifiableActuatableProperty,
#         g36:AnalogOut ;
#     rdfs:label "Damper Position Command Property 42" ;
#     qudt:hasQuantityKind s223:QuantityKind-RelativePosition ;
#     qudt:unit unit:PERCENT .
#
# ex:HotWaterCoilAirInlet a s223:InletConnectionPoint ;
#     s223:connectsThrough ex:AirAfterDamperBeforeHeatingCoil ;
#     s223:hasMedium s223:Medium-Air .
#
# ex:HotWaterCoilAirOutlet a s223:OutletConnectionPoint ;
#     s223:connectsThrough ex:DischargeAir42 ;
#     s223:hasMedium s223:Medium-Air ;
#     s223:mapsTo ex:VAVOutlet42 .
#
# ex:HotWaterCoilWaterInlet a s223:InletConnectionPoint ;
#     s223:connectsThrough ex:HotWaterReturnAfterValve ;
#     s223:hasMedium s223:Medium-Water .
#
# ex:HotWaterCoilWaterOutlet a s223:OutletConnectionPoint ;
#     s223:connectsThrough ex:HotWaterSupply ;
#     s223:hasMedium s223:Medium-Water .
#
# ex:HotWaterReturnBeforeValve a s223:Connection ;
#     rdfs:label "Hot Water Return Before Valve" ;
#     s223:hasMedium s223:Medium-Water .
#
# ex:HotWaterSupply a s223:Connection ;
#     rdfs:label "Hot Water Supply" ;
#     s223:hasMedium s223:Medium-Water .
#
# ex:HotWaterValveInlet a s223:InletConnectionPoint ;
#     s223:connectsThrough ex:HotWaterReturnBeforeValve ;
#     s223:hasMedium s223:Medium-Water .
#
# ex:HotWaterValveOutlet a s223:OutletConnectionPoint ;
#     s223:connectsThrough ex:HotWaterReturnAfterValve ;
#     s223:hasMedium s223:Medium-Water .
#
# ex:HotWaterValveSignal a s223:QuantifiableActuatableProperty,
#         g36:AnalogOut ;
#     rdfs:label "Hot Water Valve Signal" ;
#     qudt:hasQuantityKind s223:QuantityKind-RelativePosition ;
#     qudt:unit unit:PERCENT .
#
# ex:IndoorLight a s223:Connection ;
#     rdfs:label "Indoor Light" ;
#     s223:hasMedium ex:Medium-Light .
#
# ex:OutdoorLight a s223:Connection ;
#     rdfs:label "Outdoor Light" ;
#     s223:hasMedium ex:Medium-Light .
#
# ex:VAVReheat a g36:VAVWithReheat,
#         g36:VAV_4-2 ;
#     rdfs:label "VAV Terminal Unit with Reheat" ;
#     s223:connectedTo ex:Space1 ;
#     s223:contains ex:Damper42,
#         ex:HotWaterCoil ;
#     s223:hasConnectionPoint ex:VAVInlet42,
#         ex:VAVOutlet42 ;
#     s223:hasProperty ex:SupplyAirflow42 .
#
# ex:WindowInlet a s223:InletConnectionPoint ;
#     rdfs:label "Window Inlet" ;
#     s223:connectsThrough ex:IndoorLight ;
#     s223:hasMedium ex:Medium-Light .
#
# ex:WindowOutlet a s223:OutletConnectionPoint ;
#     rdfs:label "Window Outlet" ;
#     s223:connectsThrough ex:OutdoorLight ;
#     s223:hasMedium ex:Medium-Light .
#
# ex:ZoneCO2 a s223:QuantifiableObservableProperty,
#         g36:AnalogIn ;
#     rdfs:label "Zone CO2 Property" ;
#     s223:ofSubstance s223:Substance-CO2 ;
#     qudt:hasQuantityKind quantitykind:Concentration ;
#     qudt:unit unit:PPM .
#
# ex:ZoneOccupancy a g36:BinaryIn ;
#     rdfs:label "Zone Occupancy Property" ;
#     s223:hasEnumerationKind g36:RunStatus .
#
# ex:ZoneTemp a s223:QuantifiableObservableProperty,
#         g36:AnalogIn ;
#     rdfs:label "Zone Temperature Property" ;
#     qudt:hasQuantityKind quantitykind:Temperature ;
#     qudt:unit unit:DEG_C .
#
# ex:AirAfterDamperBeforeHeatingCoil a s223:Connection ;
#     rdfs:label "Air After Damper Before Heating Coil" ;
#     s223:hasMedium s223:Medium-Air .
#
# ex:DamperInlet42 a s223:InletConnectionPoint ;
#     rdfs:label "Damper Inlet 42" ;
#     s223:connectsThrough ex:SupplyAir42 ;
#     s223:hasMedium s223:Medium-Air ;
#     s223:mapsTo ex:VAVInlet42 .
#
# ex:DischargeAir42 a s223:Connection ;
#     rdfs:label "Discharge Air 42" ;
#     s223:hasMedium s223:Medium-Air .
#
# ex:HotWaterCoil a g36:HotWaterCoil ;
#     s223:connectedTo ex:HotWaterValve ;
#     s223:contains ex:HotWaterValve ;
#     s223:hasConnectionPoint ex:HotWaterCoilAirInlet,
#         ex:HotWaterCoilAirOutlet,
#         ex:HotWaterCoilWaterInlet,
#         ex:HotWaterCoilWaterOutlet ;
#     s223:hasRole s223:HeatExchanger-Heating .
#
# ex:HotWaterReturnAfterValve a s223:Connection ;
#     rdfs:label "Hot Water Return After Valve" ;
#     s223:hasMedium s223:Medium-Water .
#
# ex:HotWaterValve a s223:Valve,
#         g36:HotWaterValve ;
#     s223:hasConnectionPoint ex:HotWaterValveInlet,
#         ex:HotWaterValveOutlet ;
#     s223:hasProperty ex:HotWaterValveSignal .
#
# ex:Space1 a s223:DomainSpace ;
#     rdfs:label "The Space 1" ;
#     s223:connectedTo ex:Window ;
#     s223:hasDomain s223:Domain-HVAC .
#
# ex:SupplyAir42 a s223:Connection ;
#     rdfs:label "Supply Air 42" ;
#     s223:hasMedium s223:Medium-Air .
#
# ex:SupplyAirflow42 a s223:QuantifiableObservableProperty,
#         g36:AnalogIn ;
#     rdfs:label "Supply Airflow Property" ;
#     qudt:hasQuantityKind quantitykind:VolumeFlowRate ;
#     qudt:unit unit:L-PER-SEC .
#
# ex:VAVInlet42 a s223:InletConnectionPoint ;
#     rdfs:label "VAV Inlet" ;
#     s223:connectsThrough ex:SupplyAir42 ;
#     s223:hasMedium s223:Medium-Air .
#
# ex:VAVOutlet42 a s223:OutletConnectionPoint ;
#     rdfs:label "VAV Outlet" ;
#     s223:connectsThrough ex:DischargeAir42 ;
#     s223:hasMedium s223:Medium-Air ;
#     s223:hasProperty ex:VAVSupplyAirTemp .
#
# ex:VAVSupplyAirTemp a s223:QuantifiableObservableProperty,
#         g36:AnalogIn ;
#     rdfs:label "VAV Supply Air Temperature Property" ;
#     qudt:hasQuantityKind quantitykind:Temperature ;
#     qudt:unit unit:DEG_C .
#
# ex:Window a s223:Window ;
#     rdfs:label "Window" ;
#     s223:hasConnectionPoint ex:WindowInlet,
#         ex:WindowOutlet .
#
# ex:WindowSwitchOnOff a g36:BinaryIn ;
#     rdfs:label "Window Switch Property" ;
#     s223:hasEnumerationKind g36:RunStatus .
#
# ex:Medium-Light a s223:EnumerationKind-Medium,
#         s223:Medium-Light .

# %% [markdown]
# # Validate with BuildingMOTIF

# %%
validation_result = model.validate(all_shape_graphs)
print(f"Model is valid? {validation_result.valid}")
print("-"*79) # just a separator for better error display
print(validation_result.report_string)
print("-"*79) # just a separator for better error display
print("Model is invalid for these reasons:")
for diff in validation_result.diffset:
    print(f" - {diff.reason()}")
# Out:
# Model is valid? False
# -------------------------------------------------------------------------------
# Validation Report
# Conforms: False
# Results (18):
# Validation Result in ClassConstraintComponent (http://www.w3.org/ns/shacl#ClassConstraintComponent):
# 	Severity: <http://data.ashrae.org/standard223#g36>
# 	Source Shape: [ sh:class <http://data.ashrae.org/standard223/1.0/extension/g36#HotWaterValve> ; sh:comment Literal("Must have Valve Connected.") ; sh:minCount Literal("1", datatype=xsd:integer) ; sh:path [ sh:alternativePath ( <http://data.ashrae.org/standard223#connectedFrom> <http://data.ashrae.org/standard223#connectedTo> ) ] ; sh:severity <http://data.ashrae.org/standard223#g36> ]
# 	Focus Node: ex:HotWaterCoil
# 	Value Node: ex:Damper42
# 	Result Path: [ sh:alternativePath ( <http://data.ashrae.org/standard223#connectedFrom> <http://data.ashrae.org/standard223#connectedTo> ) ]
# 	Message: Value does not have class <http://data.ashrae.org/standard223/1.0/extension/g36#HotWaterValve>
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ rdfs:comment Literal("Make sure that a containing Equipment inherits the outgoing connectedTo relations of contained Equipment if they are not internal connections.") ; sh:path <http://data.ashrae.org/standard223#connectedTo> ; sh:sparql [ rdf:type sh:SPARQLConstraint ; rdfs:comment Literal("Make sure that a containing Equipment inherits the outgoing connectedTo relations of contained Equipment if they are not internal connections.") ; sh:message Literal("{?container} does not have a connectedTo relation to {?otherDev} even though {?container} contains {$this} which does.") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/model> ; sh:select Literal("
# SELECT $this ?container ?otherDev
# WHERE {
# $this s223:connectedTo ?otherDev .
# $this ^s223:contains ?container .
# FILTER NOT EXISTS {?container s223:contains ?otherDev .}
# FILTER NOT EXISTS {?container s223:connectedTo ?otherDev .}
# }
# ") ] ]
# 	Focus Node: ex:HotWaterCoil
# 	Result Path: <http://data.ashrae.org/standard223#connectedTo>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; rdfs:comment Literal("Make sure that a containing Equipment inherits the outgoing connectedTo relations of contained Equipment if they are not internal connections.") ; sh:message Literal("{?container} does not have a connectedTo relation to {?otherDev} even though {?container} contains {$this} which does.") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/model> ; sh:select Literal("
# SELECT $this ?container ?otherDev
# WHERE {
# $this s223:connectedTo ?otherDev .
# $this ^s223:contains ?container .
# FILTER NOT EXISTS {?container s223:contains ?otherDev .}
# FILTER NOT EXISTS {?container s223:connectedTo ?otherDev .}
# }
# ") ]
# 	Message: http://example.org#VAVReheat does not have a connectedTo relation to http://example.org#HotWaterValve even though http://example.org#VAVReheat contains http://example.org#HotWaterCoil which does.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ rdfs:comment Literal("Make sure that a containing Equipment inherits the incoming connectedFrom relations of contained Equipment if they are not internal connections.") ; sh:path <http://data.ashrae.org/standard223#connectedFrom> ; sh:sparql [ rdf:type sh:SPARQLConstraint ; rdfs:comment Literal("Make sure that a containing Equipment inherits the incoming connectedFrom relations of contained Equipment if they are not internal connections.") ; sh:message Literal("{?container} does not have a connectedFrom relation to {?otherDev} even though {?container} contains {$this} which does.") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/model> ; sh:select Literal("
# SELECT $this ?container ?otherDev
# WHERE {
# $this s223:connectedFrom ?otherDev .
# $this ^s223:contains ?container .
# FILTER NOT EXISTS {?container s223:contains ?otherDev .}
# FILTER NOT EXISTS {?container s223:connectedFrom ?otherDev .}
# }
# ") ] ]
# 	Focus Node: ex:HotWaterValve
# 	Result Path: <http://data.ashrae.org/standard223#connectedFrom>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; rdfs:comment Literal("Make sure that a containing Equipment inherits the incoming connectedFrom relations of contained Equipment if they are not internal connections.") ; sh:message Literal("{?container} does not have a connectedFrom relation to {?otherDev} even though {?container} contains {$this} which does.") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/model> ; sh:select Literal("
# SELECT $this ?container ?otherDev
# WHERE {
# $this s223:connectedFrom ?otherDev .
# $this ^s223:contains ?container .
# FILTER NOT EXISTS {?container s223:contains ?otherDev .}
# FILTER NOT EXISTS {?container s223:connectedFrom ?otherDev .}
# }
# ") ]
# 	Message: http://example.org#HotWaterCoil does not have a connectedFrom relation to http://example.org#HotWaterCoil even though http://example.org#HotWaterCoil contains http://example.org#HotWaterValve which does.
# Validation Result in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Info
# 	Source Shape: [ rdfs:comment Literal("This DomainSpace must eventually be enclosed by a PhysicalSpace.") ; sh:message Literal("This DomainSpace must eventually be enclosed by a PhysicalSpace.") ; sh:minCount Literal("1", datatype=xsd:integer) ; sh:path [ sh:inversePath <http://data.ashrae.org/standard223#encloses> ] ; sh:severity sh:Info ]
# 	Focus Node: ex:Space1
# 	Result Path: [ sh:inversePath <http://data.ashrae.org/standard223#encloses> ]
# 	Message: This DomainSpace must eventually be enclosed by a PhysicalSpace.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ rdfs:comment Literal("This Class must have a label") ; sh:path rdfs:label ; sh:sparql [ rdf:type sh:SPARQLConstraint ; sh:message Literal("{$this} must have an rdfs:label") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/schema> ; sh:select Literal("
# SELECT $this
# WHERE {
# FILTER (NOT EXISTS {$this rdfs:label ?something}) .
# }
# ") ] ]
# 	Focus Node: s223:QuantityKind-RelativePosition
# 	Result Path: rdfs:label
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("{$this} must have an rdfs:label") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/schema> ; sh:select Literal("
# SELECT $this
# WHERE {
# FILTER (NOT EXISTS {$this rdfs:label ?something}) .
# }
# ") ]
# 	Message: http://data.ashrae.org/standard223#QuantityKind-RelativePosition must have an rdfs:label
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ rdfs:comment Literal("This Class must have a label") ; sh:path rdfs:label ; sh:sparql [ rdf:type sh:SPARQLConstraint ; sh:message Literal("{$this} must have an rdfs:label") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/schema> ; sh:select Literal("
# SELECT $this
# WHERE {
# FILTER (NOT EXISTS {$this rdfs:label ?something}) .
# }
# ") ] ]
# 	Focus Node: g36:VAV_4-1
# 	Result Path: rdfs:label
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("{$this} must have an rdfs:label") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/schema> ; sh:select Literal("
# SELECT $this
# WHERE {
# FILTER (NOT EXISTS {$this rdfs:label ?something}) .
# }
# ") ]
# 	Message: http://data.ashrae.org/standard223/1.0/extension/g36#VAV_4-1 must have an rdfs:label
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ rdfs:comment Literal("This Class must have a label") ; sh:path rdfs:label ; sh:sparql [ rdf:type sh:SPARQLConstraint ; sh:message Literal("{$this} must have an rdfs:label") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/schema> ; sh:select Literal("
# SELECT $this
# WHERE {
# FILTER (NOT EXISTS {$this rdfs:label ?something}) .
# }
# ") ] ]
# 	Focus Node: g36:TemperatureSensor
# 	Result Path: rdfs:label
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("{$this} must have an rdfs:label") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/schema> ; sh:select Literal("
# SELECT $this
# WHERE {
# FILTER (NOT EXISTS {$this rdfs:label ?something}) .
# }
# ") ]
# 	Message: http://data.ashrae.org/standard223/1.0/extension/g36#TemperatureSensor must have an rdfs:label
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ rdfs:comment Literal("This Class must have a label") ; sh:path rdfs:label ; sh:sparql [ rdf:type sh:SPARQLConstraint ; sh:message Literal("{$this} must have an rdfs:label") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/schema> ; sh:select Literal("
# SELECT $this
# WHERE {
# FILTER (NOT EXISTS {$this rdfs:label ?something}) .
# }
# ") ] ]
# 	Focus Node: g36:VAV_4-2
# 	Result Path: rdfs:label
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("{$this} must have an rdfs:label") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/schema> ; sh:select Literal("
# SELECT $this
# WHERE {
# FILTER (NOT EXISTS {$this rdfs:label ?something}) .
# }
# ") ]
# 	Message: http://data.ashrae.org/standard223/1.0/extension/g36#VAV_4-2 must have an rdfs:label
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ rdfs:comment Literal("This Class must have a label") ; sh:path rdfs:label ; sh:sparql [ rdf:type sh:SPARQLConstraint ; sh:message Literal("{$this} must have an rdfs:label") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/schema> ; sh:select Literal("
# SELECT $this
# WHERE {
# FILTER (NOT EXISTS {$this rdfs:label ?something}) .
# }
# ") ] ]
# 	Focus Node: s223:QuantityKind-Occupancy
# 	Result Path: rdfs:label
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("{$this} must have an rdfs:label") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/schema> ; sh:select Literal("
# SELECT $this
# WHERE {
# FILTER (NOT EXISTS {$this rdfs:label ?something}) .
# }
# ") ]
# 	Message: http://data.ashrae.org/standard223#QuantityKind-Occupancy must have an rdfs:label
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ rdfs:comment Literal("If a CP mapsTo another CP, the respective Equipment should have a contains relation.") ; sh:path <http://data.ashrae.org/standard223#mapsTo> ; sh:sparql [ rdf:type sh:SPARQLConstraint ; rdfs:comment Literal("If a Connectable is s223:connected (high-level), it must eventually have the underlying cnx relations.") ; sh:message Literal("{$this} is s223:connected (high-level) to {?otherC} but not yet connected at the cnx-level.") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/model> ; sh:select Literal("
# SELECT $this ?otherC
# WHERE {
# $this s223:connected ?otherC .
# FILTER NOT EXISTS {$this s223:cnx+ ?otherC}
# }
# ") ; sh:severity sh:Warning ] ]
# 	Focus Node: ex:Space1
# 	Result Path: <http://data.ashrae.org/standard223#mapsTo>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; rdfs:comment Literal("If a Connectable is s223:connected (high-level), it must eventually have the underlying cnx relations.") ; sh:message Literal("{$this} is s223:connected (high-level) to {?otherC} but not yet connected at the cnx-level.") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/model> ; sh:select Literal("
# SELECT $this ?otherC
# WHERE {
# $this s223:connected ?otherC .
# FILTER NOT EXISTS {$this s223:cnx+ ?otherC}
# }
# ") ; sh:severity sh:Warning ]
# 	Message: http://example.org#Space1 is s223:connected (high-level) to http://example.org#Window but not yet connected at the cnx-level.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ rdfs:comment Literal("If a CP mapsTo another CP, the respective Equipment should have a contains relation.") ; sh:path <http://data.ashrae.org/standard223#mapsTo> ; sh:sparql [ rdf:type sh:SPARQLConstraint ; rdfs:comment Literal("If a Connectable is s223:connected (high-level), it must eventually have the underlying cnx relations.") ; sh:message Literal("{$this} is s223:connected (high-level) to {?otherC} but not yet connected at the cnx-level.") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/model> ; sh:select Literal("
# SELECT $this ?otherC
# WHERE {
# $this s223:connected ?otherC .
# FILTER NOT EXISTS {$this s223:cnx+ ?otherC}
# }
# ") ; sh:severity sh:Warning ] ]
# 	Focus Node: ex:Window
# 	Result Path: <http://data.ashrae.org/standard223#mapsTo>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; rdfs:comment Literal("If a Connectable is s223:connected (high-level), it must eventually have the underlying cnx relations.") ; sh:message Literal("{$this} is s223:connected (high-level) to {?otherC} but not yet connected at the cnx-level.") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/model> ; sh:select Literal("
# SELECT $this ?otherC
# WHERE {
# $this s223:connected ?otherC .
# FILTER NOT EXISTS {$this s223:cnx+ ?otherC}
# }
# ") ; sh:severity sh:Warning ]
# 	Message: http://example.org#Window is s223:connected (high-level) to http://example.org#Space1 but not yet connected at the cnx-level.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ rdfs:comment Literal("If a CP mapsTo another CP, the respective Equipment should have a contains relation.") ; sh:path <http://data.ashrae.org/standard223#mapsTo> ; sh:sparql [ rdf:type sh:SPARQLConstraint ; rdfs:comment Literal("If a Connectable is s223:connected (high-level), it must eventually have the underlying cnx relations.") ; sh:message Literal("{$this} is s223:connected (high-level) to {?otherC} but not yet connected at the cnx-level.") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/model> ; sh:select Literal("
# SELECT $this ?otherC
# WHERE {
# $this s223:connected ?otherC .
# FILTER NOT EXISTS {$this s223:cnx+ ?otherC}
# }
# ") ; sh:severity sh:Warning ] ]
# 	Focus Node: ex:VAVReheat
# 	Result Path: <http://data.ashrae.org/standard223#mapsTo>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; rdfs:comment Literal("If a Connectable is s223:connected (high-level), it must eventually have the underlying cnx relations.") ; sh:message Literal("{$this} is s223:connected (high-level) to {?otherC} but not yet connected at the cnx-level.") ; sh:prefixes <http://data.ashrae.org/standard223/1.0/validation/model> ; sh:select Literal("
# SELECT $this ?otherC
# WHERE {
# $this s223:connected ?otherC .
# FILTER NOT EXISTS {$this s223:cnx+ ?otherC}
# }
# ") ; sh:severity sh:Warning ]
# 	Message: http://example.org#VAVReheat is s223:connected (high-level) to http://example.org#Space1 but not yet connected at the cnx-level.
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ rdfs:comment Literal("A Sensor can be associated with at most 1 ObservableProperty by observesProperty") ; sh:class <http://data.ashrae.org/standard223#ObservableProperty> ; sh:maxCount Literal("1", datatype=xsd:integer) ; sh:minCount Literal("1", datatype=xsd:integer) ; sh:path <http://data.ashrae.org/standard223#observesProperty> ]
# 	Focus Node: ex:TemperatureSensor
# 	Result Path: <http://data.ashrae.org/standard223#observesProperty>
# 	Message: Less than 1 values on ex:TemperatureSensor-><http://data.ashrae.org/standard223#observesProperty>
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ rdfs:comment Literal("A Sensor can be associated with at most 1 ObservableProperty by observesProperty") ; sh:class <http://data.ashrae.org/standard223#ObservableProperty> ; sh:maxCount Literal("1", datatype=xsd:integer) ; sh:minCount Literal("1", datatype=xsd:integer) ; sh:path <http://data.ashrae.org/standard223#observesProperty> ]
# 	Focus Node: ex:AirFlowStation42
# 	Result Path: <http://data.ashrae.org/standard223#observesProperty>
# 	Message: Less than 1 values on ex:AirFlowStation42-><http://data.ashrae.org/standard223#observesProperty>
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ rdfs:comment Literal("A Sensor can be associated with at most 1 ObservableProperty by observesProperty") ; sh:class <http://data.ashrae.org/standard223#ObservableProperty> ; sh:maxCount Literal("1", datatype=xsd:integer) ; sh:minCount Literal("1", datatype=xsd:integer) ; sh:path <http://data.ashrae.org/standard223#observesProperty> ]
# 	Focus Node: ex:WindowSwitch
# 	Result Path: <http://data.ashrae.org/standard223#observesProperty>
# 	Message: Less than 1 values on ex:WindowSwitch-><http://data.ashrae.org/standard223#observesProperty>
# Constraint Violation in XoneConstraintComponent (http://www.w3.org/ns/shacl#XoneConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <http://data.ashrae.org/standard223#Sensor>
# 	Focus Node: ex:TemperatureSensor
# 	Value Node: ex:TemperatureSensor
# 	Message: Node ex:TemperatureSensor does not conform to exactly one shape in [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path ( <http://data.ashrae.org/standard223#observesProperty> <http://qudt.org/schema/qudt/hasQuantityKind> ) ] , [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path ( <http://data.ashrae.org/standard223#observesProperty> <http://data.ashrae.org/standard223#hasEnumerationKind> ) ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of QuantifiableObservableProperty or EnumeratedObservableProperty by observes.") ; sh:class <http://data.ashrae.org/standard223#QuantifiableObservableProperty> ; sh:path <http://data.ashrae.org/standard223#observes> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of QuantifiableObservableProperty or EnumeratedObservableProperty by observes.") ; sh:class <http://data.ashrae.org/standard223#EnumeratedObservableProperty> ; sh:path <http://data.ashrae.org/standard223#observes> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of Connectable, Connection, Segment, or ConnectionPoint by hasMeasurementLocation.") ; sh:class <http://data.ashrae.org/standard223#Connectable> ; sh:path <http://data.ashrae.org/standard223#hasMeasurementLocation> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of Connectable, Connection, Segment, or ConnectionPoint by hasMeasurementLocation.") ; sh:class <http://data.ashrae.org/standard223#Connection> ; sh:path <http://data.ashrae.org/standard223#hasMeasurementLocation> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of Connectable, Connection, Segment, or ConnectionPoint by hasMeasurementLocation.") ; sh:class <http://data.ashrae.org/standard223#Segment> ; sh:path <http://data.ashrae.org/standard223#hasMeasurementLocation> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of Connectable, Connection, Segment, or ConnectionPoint by hasMeasurementLocation.") ; sh:class <http://data.ashrae.org/standard223#ConnectionPoint> ; sh:path <http://data.ashrae.org/standard223#hasMeasurementLocation> ] ]
# Constraint Violation in XoneConstraintComponent (http://www.w3.org/ns/shacl#XoneConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <http://data.ashrae.org/standard223#Sensor>
# 	Focus Node: ex:AirFlowStation42
# 	Value Node: ex:AirFlowStation42
# 	Message: Node ex:AirFlowStation42 does not conform to exactly one shape in [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path ( <http://data.ashrae.org/standard223#observesProperty> <http://qudt.org/schema/qudt/hasQuantityKind> ) ] , [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path ( <http://data.ashrae.org/standard223#observesProperty> <http://data.ashrae.org/standard223#hasEnumerationKind> ) ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of QuantifiableObservableProperty or EnumeratedObservableProperty by observes.") ; sh:class <http://data.ashrae.org/standard223#QuantifiableObservableProperty> ; sh:path <http://data.ashrae.org/standard223#observes> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of QuantifiableObservableProperty or EnumeratedObservableProperty by observes.") ; sh:class <http://data.ashrae.org/standard223#EnumeratedObservableProperty> ; sh:path <http://data.ashrae.org/standard223#observes> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of Connectable, Connection, Segment, or ConnectionPoint by hasMeasurementLocation.") ; sh:class <http://data.ashrae.org/standard223#Connectable> ; sh:path <http://data.ashrae.org/standard223#hasMeasurementLocation> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of Connectable, Connection, Segment, or ConnectionPoint by hasMeasurementLocation.") ; sh:class <http://data.ashrae.org/standard223#Connection> ; sh:path <http://data.ashrae.org/standard223#hasMeasurementLocation> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of Connectable, Connection, Segment, or ConnectionPoint by hasMeasurementLocation.") ; sh:class <http://data.ashrae.org/standard223#Segment> ; sh:path <http://data.ashrae.org/standard223#hasMeasurementLocation> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of Connectable, Connection, Segment, or ConnectionPoint by hasMeasurementLocation.") ; sh:class <http://data.ashrae.org/standard223#ConnectionPoint> ; sh:path <http://data.ashrae.org/standard223#hasMeasurementLocation> ] ]
# Constraint Violation in XoneConstraintComponent (http://www.w3.org/ns/shacl#XoneConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <http://data.ashrae.org/standard223#Sensor>
# 	Focus Node: ex:WindowSwitch
# 	Value Node: ex:WindowSwitch
# 	Message: Node ex:WindowSwitch does not conform to exactly one shape in [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path ( <http://data.ashrae.org/standard223#observesProperty> <http://qudt.org/schema/qudt/hasQuantityKind> ) ] , [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path ( <http://data.ashrae.org/standard223#observesProperty> <http://data.ashrae.org/standard223#hasEnumerationKind> ) ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of QuantifiableObservableProperty or EnumeratedObservableProperty by observes.") ; sh:class <http://data.ashrae.org/standard223#QuantifiableObservableProperty> ; sh:path <http://data.ashrae.org/standard223#observes> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of QuantifiableObservableProperty or EnumeratedObservableProperty by observes.") ; sh:class <http://data.ashrae.org/standard223#EnumeratedObservableProperty> ; sh:path <http://data.ashrae.org/standard223#observes> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of Connectable, Connection, Segment, or ConnectionPoint by hasMeasurementLocation.") ; sh:class <http://data.ashrae.org/standard223#Connectable> ; sh:path <http://data.ashrae.org/standard223#hasMeasurementLocation> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of Connectable, Connection, Segment, or ConnectionPoint by hasMeasurementLocation.") ; sh:class <http://data.ashrae.org/standard223#Connection> ; sh:path <http://data.ashrae.org/standard223#hasMeasurementLocation> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of Connectable, Connection, Segment, or ConnectionPoint by hasMeasurementLocation.") ; sh:class <http://data.ashrae.org/standard223#Segment> ; sh:path <http://data.ashrae.org/standard223#hasMeasurementLocation> ] ] , [ sh:property [ rdfs:comment Literal("A Sensor must be associated with exactly 1 of Connectable, Connection, Segment, or ConnectionPoint by hasMeasurementLocation.") ; sh:class <http://data.ashrae.org/standard223#ConnectionPoint> ; sh:path <http://data.ashrae.org/standard223#hasMeasurementLocation> ] ]
#
# -------------------------------------------------------------------------------
# Model is invalid for these reasons:
#  - http://example.org#Space1 needs between 1 and None uses of path nb66f63e3a155446eb189e3cab917d774b103
#  - http://example.org#HotWaterCoil needs to be a http://data.ashrae.org/standard223/1.0/extension/g36#HotWaterValve
#  - http://example.org#AirFlowStation42 needs between 1 and 1 instances of http://data.ashrae.org/standard223#ObservableProperty on path http://data.ashrae.org/standard223#observesProperty
#  - http://example.org#WindowSwitch needs between 1 and 1 instances of http://data.ashrae.org/standard223#ObservableProperty on path http://data.ashrae.org/standard223#observesProperty
#  - http://example.org#TemperatureSensor needs between 1 and 1 instances of http://data.ashrae.org/standard223#ObservableProperty on path http://data.ashrae.org/standard223#observesProperty

# %% [markdown]
# # Generate Templates

# %%
# We first create a new template library by adding any name you like to the new template library. 
# This new template library is stored in the "generated_templates" variable
generated_templates = Library.create("any_template_library_name_you_like")

# %%
# We then use the following code to auto-generate ".ttl" templates and add them to the "generated_templates" variable. 
# For each failed validation item "diff", one template is auto-generated
for diff in validation_result.diffset:
    try:
        diff.resolve(generated_templates)
        print("--------iteration---------------")
    except:
        pass
# Out:
# --------iteration---------------
# --------iteration---------------
# --------iteration---------------
# --------iteration---------------

# %%
# Print the auto-generated templates. For each auto-generated template, the template name, the template parameters, and the template body are printed. 
for template in generated_templates.get_templates():
    template = template.inline_dependencies()
    print(f"Name (autogenerated): {template.name}")
    print(f"Parameters (autogenerated): {template.parameters}")
    print("Template body (autogenerated):")
    print(template.body.serialize())
    print("-"*79) # just a separator for better display
# Out:
# Name (autogenerated): resolve97d09f33
# Parameters (autogenerated): set()
# Template body (autogenerated):
#
#
# -------------------------------------------------------------------------------
# Name (autogenerated): resolveb1d91094
# Parameters (autogenerated): set()
# Template body (autogenerated):
# @prefix ex: <http://example.org#> .
# @prefix g36: <http://data.ashrae.org/standard223/1.0/extension/g36#> .
#
# ex:HotWaterCoil a g36:HotWaterValve .
#
#
# -------------------------------------------------------------------------------
# Name (autogenerated): resolve_c08f4352
# Parameters (autogenerated): {'p2'}
# Template body (autogenerated):
# @prefix ex: <http://example.org#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
#
# ex:AirFlowStation42 s223:observesProperty <urn:___param___#p2> .
#
# <urn:___param___#p2> a s223:ObservableProperty .
#
#
# -------------------------------------------------------------------------------
# Name (autogenerated): resolve_c5709d02
# Parameters (autogenerated): {'p3'}
# Template body (autogenerated):
# @prefix ex: <http://example.org#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
#
# ex:WindowSwitch s223:observesProperty <urn:___param___#p3> .
#
# <urn:___param___#p3> a s223:ObservableProperty .
#
#
# -------------------------------------------------------------------------------
# Name (autogenerated): resolve_4fd2905f
# Parameters (autogenerated): {'p4'}
# Template body (autogenerated):
# @prefix ex: <http://example.org#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
#
# ex:TemperatureSensor s223:observesProperty <urn:___param___#p4> .
#
# <urn:___param___#p4> a s223:ObservableProperty .
#
#
# -------------------------------------------------------------------------------
